# %%
import pandas as pd

# %%
df = pd.read_excel('https://travel.trade.gov/view/m-2017-I-001/documents/Final%20COR%20Volume.xlsx')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Volume (F)', 'Volume (F).1',
#        'Volume (F).2', 'Volume (F).3', 'Volume (F).4', 'Volume (F).5',
#        'Volume (R)', 'Volume (P)', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Percent Change', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Market Share', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')

# %%
df_2016 = pd.read_csv('Final COR Volume/2016 COR Month-QTR Volume-Table 1.csv', header = 1)

# %%
df_2017 = pd.read_csv('Final COR Volume/2017 COR Month-QTR Volume -Table 1.csv', header = 1)

# %%
df_2018 = pd.read_csv('Final COR Volume/2018 COR Month-QTR Volume -Table 1.csv', header = 1)

# %%
just_nums_2016 = df_2016.iloc[:,1:18]

# %%
just_nums_2016 = just_nums_2016.transpose()

# %%
just_nums_2016 = just_nums_2016.rename(columns=just_nums_2016.iloc[0])

# %%
just_nums_2016.drop(just_nums_2016.index[0])
# Out:
#        TOTAL INTERNATIONAL (Overseas, Mexico, and Canada)  NaN  \
# Jan-16                                          5,614,591  NaN
# Feb-16                                          4,935,260  NaN
# Mar-16                                          6,143,910  NaN
# Q1-16                                          16,693,761  NaN
# Apr-16                                          6,042,233  NaN
# May-16                                          6,500,006  NaN
# Jun-16                                          6,154,158  NaN
# Q2-16                                          18,696,397  NaN
# Jul-16                                          7,594,735  NaN
# Aug-16                                          7,895,284  NaN
# Sep-16                                          6,614,195  NaN
# Q3-16                                          22,104,214  NaN
# Oct-16                                          6,723,729  NaN
# Nov-16                                          5,844,020  NaN
# ...

# %%
just_nums_2017 = df_2017.iloc[:,1:18]

# %%
just_nums_2017.shape
# Out:
# (92, 17)

# %%
just_nums_2017 = just_nums_2017.dropna(subset = ['I-94 Arrivals based on Country of Residence (COR)'])

# %%
just_nums_2017.head()
# Out:
#    I-94 Arrivals based on Country of Residence (COR)     Jan-17     Feb-17  \
# 0  TOTAL INTERNATIONAL (Overseas, Mexico, and Can...  5,767,752  4,851,902
# 2                                    TOTAL OVERSEAS   2,809,419  2,386,406
# 3               Total Canada (Source: Stats Canada)   1,473,657  1,289,479
# 4                 Canada Air (Source: Stats Canada)     778,546    736,362
# 5            Total Mexico (Source: Banco de Mexico)   1,484,676  1,176,017
#
#       Mar-17       Q1-17     Apr-17     May-17     Jun-17       Q2-17  \
# 0  5,793,626  16,413,280  6,700,656  6,253,889  6,076,727  19,031,272
# 2  2,764,000   7,959,825  3,315,526  3,267,355  3,400,431   9,983,312
# 3  1,842,583   4,605,719  1,848,622  1,590,497  1,448,867   4,887,986
# 4    928,910   2,443,818    842,062    652,020    590,592   2,084,674
# 5  1,187,043   3,847,736  1,536,508  1,396,037  1,227,429   4,159,974
#
#       Jul-17     Aug-17     Sep-17       Q3-17     Oct-17     Nov-17  \
# ...

# %%
just_nums_2017 = just_nums_2017.drop(columns = ['Q1-17', 'Q2-17', 'Q3-17', 'Q4-17'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = just_nums_2017.columns[1:]

# %%
just_nums_2017.iloc[1:2,1:]
# Out:
#       Jan-17     Feb-17     Mar-17     Apr-17     May-17     Jun-17  \
# 2  2,809,419  2,386,406  2,764,000  3,315,526  3,267,355  3,400,431
#
#       Jul-17     Aug-17     Sep-17     Oct-17     Nov-17     Dec-17
# 2  3,952,772  4,027,400  3,392,091  3,426,969  2,802,071  3,361,084

# %%
sns.barplot(just_nums_2017)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-a9410a77ad00> in <module>
# ----> 1 sns.barplot(just_nums_2017)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.load_dataset("car_crashes").sort_values("total", ascending=False)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 17   21.4     4.066    4.922          16.692       16.264       872.51
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
# 36   19.9     6.368    5.771          18.308       18.706       881.51
# 42   19.5     4.095    5.655          15.990       15.795       767.91
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 41   19.4     6.014    6.402          19.012       16.684       669.31
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# ...
